# %%
suppressPackageStartupMessages({
    library(Seurat)
    library(SingleR)
    library(celldex)
})

# %%
obj <- get(load(file = "data/MS/MS_PBMC_filtered_monaco_GSE138266.Rda"))
blueprint.ref <- celldex::BlueprintEncodeData()
sce <- LayerData(obj)
blueprint.fine <- SingleR(test = sce, assay.type.test = 1, ref = blueprint.ref, labels = blueprint.ref$label.fine)
obj@meta.data$blueprint.fine <- blueprint.fine$pruned.labels

save(obj, file = "data/MS/MS_PBMC_filtered_monaco_GSE138266_2.rda")

# %%
obj <- get(load(file = "data/SLE/SLE_Seurat_filtered_monaco_GSE135779.Rda"))
blueprint.ref <- celldex::BlueprintEncodeData()
sce <- LayerData(obj)
blueprint.fine <- SingleR(test = sce, assay.type.test = 1, ref = blueprint.ref, labels = blueprint.ref$label.fine)
obj@meta.data$blueprint.fine <- blueprint.fine$pruned.labels

save(obj, file = "data/SLE/SLE_Seurat_filtered_monaco_GSE135779_2.rda")

# %%
obj <- get(load(file = "data/SJ/Sjogren_Seurat_filtered_monaco_GSE157278.Rda"))
blueprint.ref <- celldex::BlueprintEncodeData()
sce <- LayerData(obj)
blueprint.fine <- SingleR(test = sce, assay.type.test = 1, ref = blueprint.ref, labels = blueprint.ref$label.fine)
obj@meta.data$blueprint.fine <- blueprint.fine$pruned.labels

save(obj, file = "data/SJ/Sjogren_Seurat_filtered_monaco_GSE157278_2.rda")

# %%
obj <- get(load(file = "data/RA/AMP_RA_OA_Phase1_Phase2_scRNAseq_monaco.Rda"))
blueprint.ref <- celldex::BlueprintEncodeData()
sce <- LayerData(obj)
blueprint.fine <- SingleR(test = sce, assay.type.test = 1, ref = blueprint.ref, labels = blueprint.ref$label.fine)
obj@meta.data$blueprint.fine <- blueprint.fine$pruned.labels

save(obj, file = "data/RA/AMP_RA_OA_Phase1_Phase2_scRNAseq_monaco_2.rda")
# Out:
# see ?celldex and browseVignettes('celldex') for documentation
#
# loading from cache
#
# see ?celldex and browseVignettes('celldex') for documentation
#
# loading from cache
